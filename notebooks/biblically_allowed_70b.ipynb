# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nltk, torch, tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer
from IPython.display import clear_output, display, HTML

import infer_biblically

nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
model_name = "meta-llama/Llama-3.3-70B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.bfloat16, device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
word_mentions = {}
token_trie = infer_biblically.TokenTrie()
verses = list(infer_biblically.kjv_verses("kjv.txt"))
for verse, _, words in tqdm.tqdm(verses):
    token_trie.add_verse(verse, words, tokenizer)
    word_mentions.setdefault(verse.lower(), []).append(verse)
    for word in words:
        word_mentions.setdefault(word.lower(), []).append(verse)

can_end_word = infer_biblically.tokens_that_can_end_word(tokenizer)
# Out:
# 00%|████████████████████████████████████████████████████████████| 31102/31102 [00:25<00:00, 1237.01it/s]

# %%
def render_html(messages):
    html = []
    for m in messages:
        html.append(f"""<p><strong>{m['role']}</strong>: """)
        if m["role"] == "user":
            html.append(f"<span>{m['content']}</span>")
        else:
            for i, spaced_part in enumerate(m["content"].split(" ")):
                if i > 0:
                    html.append(" ")
                for word in nltk.word_tokenize(spaced_part):
                    if word.lower() in word_mentions:
                        verses = word_mentions[word.lower()]
                        verses_str = ", ".join(verses[:5]) + "..." if len(verses) > 5 else ", ".join(verses)
                        html.append(f"""<span title="{verses_str}">{word}</span>""")
                    else:
                        html.append(f"""<span style="border: 1px solid red">{word}</span>""")
        html.append("</p>")
    return HTML("".join(html))

# %% [markdown]
# (*If you hover over words in the assistant's responses below, it will show the first five verses the word appears in.*)

# %%
messages = []
try:
    while True:
        q = input("> ")
        messages.append({"role": "user", "content": q.strip()})
        inp = tokenizer.apply_chat_template(messages, add_generation_prompt=True)
        messages.append({"role": "assistant", "content": ""})
        for p in infer_biblically.generate(model, tokenizer, inp, 128, token_trie, can_end_word):
            messages[-1]["content"] += p
            clear_output(wait=True)
            display(render_html(messages))
except (KeyboardInterrupt, EOFError):
    print("\nQuit.")
# Out:
# <p><strong>user</strong>: <span>Hello! What are you?</span></p><p><strong>assistant</strong>: <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Genesis 1:11, Genesis 1:12, Genesis 1:12, Genesis 1:21, Genesis 1:21...">kind</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:6, Genesis 1:10...">of</span> <span title="Genesis 4:22, Isaiah 3:3">artificer</span> <span title="Genesis 13:9, Genesis 17:12, Genesis 24:21, Genesis 24:49, Genesis 24:50...">or</span> <span title="Exodus 20:25, Exodus 32:4, Deuteronomy 27:5, 1 Kings 6:7">tool</span> <span title="Genesis 1:4, Genesis 1:10, Genesis 1:12, Genesis 1:18, Genesis 1:20...">that</span> <span title="Acts 27:17, 1 Corinthians 12:28">helps</span> <span title="Genesis 11:6, Genesis 14:16, Genesis 17:14, Genesis 17:16, Genesis 19:4...">people</span> <span title="Genesis 12:1, Genesis 19:14, Genesis 22:2, Genesis 31:13, Genesis 34:4...">get</span> <span title="﻿Genesis 1:1, ﻿Genesis 1:1, ﻿Genesis 1:1, Genesis 1:2, Genesis 1:2...">the</span> <span title="Job 21:34, Job 34:36, Luke 2:47">answers</span> <span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:2...">and</span> <span title="Genesis 2:18, Genesis 2:20, Genesis 49:25, Exodus 18:4, Exodus 23:5...">help</span> <span title="Genesis 2:4, Genesis 2:24, Genesis 2:25, Genesis 3:7, Genesis 3:7...">they</span> <span title="Deuteronomy 15:8, 1 Samuel 21:15, 2 Chronicles 2:16, 2 Chronicles 20:17, Ezra 6:9...">need</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 2:23, Genesis 2:23, Genesis 4:9, Genesis 4:13, Genesis 4:23...">My</span> <span title="Genesis 2:11, Genesis 2:13, Genesis 2:14, Genesis 2:19, Genesis 3:20...">name</span> <span title="Genesis 1:11, Genesis 1:29, Genesis 1:29, Genesis 1:30, Genesis 2:9...">is</span> <span title="Judges 11:40, Isaiah 3:26, Isaiah 19:8, Isaiah 32:12, Jeremiah 4:8...">Lament</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span></p><p><strong>user</strong>: <span>Can you describe how you work, briefly?</span></p><p><strong>assistant</strong>: <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 2:2, Genesis 2:2, Genesis 2:3, Genesis 5:29, Exodus 5:9...">work</span> <span title="Genesis 7:2, Genesis 7:2, Genesis 7:3, Genesis 9:6, Genesis 9:11...">by</span> <span title="Colossians 2:22, 1 Peter 2:16">using</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Genesis 34:21, Exodus 3:8, Judges 18:10, 2 Samuel 22:20, Nehemiah 4:19...">large</span> <span title="Genesis 11:1, Genesis 11:6, Genesis 11:7, Genesis 11:9, 2 Kings 18:26...">language</span> <span title="Exodus 31:3, Exodus 35:31, Exodus 36:1, Deuteronomy 1:13, Deuteronomy 4:6...">understanding</span> <span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:2...">and</span> <span title="Genesis 7:1, Genesis 15:16, Genesis 50:23, Exodus 1:6, Exodus 17:16...">generation</span> <span title="Leviticus 27:8, Ezra 2:69, Nehemiah 5:8, Daniel 1:4, Matthew 25:15...">ability</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 2:4, Genesis 3:6, Genesis 4:8, Genesis 4:12, Genesis 5:2...">When</span> <span title="Genesis 1:29, Genesis 1:29, Genesis 9:2, Genesis 9:2, Genesis 9:3...">you</span> <span title="Genesis 32:29, Genesis 34:12, Numbers 27:21, Deuteronomy 4:32, Deuteronomy 4:32...">ask</span> <span title="Genesis 3:12, Genesis 3:12, Genesis 3:13, Genesis 4:10, Genesis 4:14...">me</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7..."> ...
# Quit.

# %%
def mk_table(tokens_to_ouch, ouch_preds, pos, n):
    html = "<table style='display: block; font-size: 10px'><tr><th>pred</th><th>→</th><th colspan=10 style='text-align: left'>options</th></tr>"
    for i in range(n):
        html += f"<tr style='text-align: left; border-top: 1px solid grey'><td><code style='white-space: nowrap'>{tokenizer.decode([tokens_to_ouch[pos + i]])!r}</code></td><td>→</td>"
        for t in ouch_preds[0, i, :]:
            cell = f"<code style='white-space: nowrap'>{tokenizer.decode([t.item()])!r}</code>"
            if t.item() == tokens_to_ouch[pos + i + 1]:
                cell = f"<span style='border: 2px solid green; padding: 2px'>{cell}</span>"
            html += f"<td style='display: inline-block'>{cell}</td>"
        html += "</tr>"
    return HTML(html + "</table>")

# %%
tokens_to_ouch = tokenizer.apply_chat_template(messages)
pos, n = 396, 4
print("pred = ..." + tokenizer.decode(tokens_to_ouch[:pos+n])[-150:])
logits = model(input_ids=torch.tensor([tokens_to_ouch]).to(model.device)).logits[:, pos:pos+n, :].detach().cpu()
ouch_preds = torch.argsort(logits, descending=True, dim=2)[:, :, :50]
mk_table(tokens_to_ouch, ouch_preds, pos, n)
# Out:
# pred = ... and the language I used to answer your questions ( lots of simple sentences and somewhat archer or old fashioned language) I would take a wild ouches
# <table style='display: block; font-size: 10px'><tr><th>pred</th><th>→</th><th colspan=10 style='text-align: left'>options</th></tr><tr style='text-align: left; border-top: 1px solid grey'><td><code style='white-space: nowrap'>' wild'</code></td><td>→</td><td style='display: inline-block'><code style='white-space: nowrap'>' guess'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' stab'</code></td><td style='display: inline-block'><span style='border: 2px solid green; padding: 2px'><code style='white-space: nowrap'>' '</code></span></td><td style='display: inline-block'><code style='white-space: nowrap'>' educated'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' and'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' speculation'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' speculative'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' chance'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' conject'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' but'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' leap'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' hypothesis'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' qu'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' estimate'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' g'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' guest'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' shot'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' inference'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' bet'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>'-g'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' "'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' spec'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>','</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' swing'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' theory'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' a'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' card'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' guessing'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' guesses'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' wild'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' Guess'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' assumption'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' prediction'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' to'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' h'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' probability'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' possibility'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' idea'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' hypothetical'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' G'</code></td><td style='display: inline-block'><code style='white-space: nowrap'>' estimation'</code></td><td style='display: inline-block'><code style='white-space: n ...

# %%
[[tokenizer.decode(t) for t in tokenizer.encode(s, add_special_tokens=False)] for s in (" ouch", " unction")]
# Out:
# [[' ', 'ouch'], [' ', 'unction']]

# %%
render_html(long_convo)
# Out:
# <p><strong>user</strong>: <span>Hello! What are you?</span></p><p><strong>assistant</strong>: <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Genesis 1:11, Genesis 1:12, Genesis 1:12, Genesis 1:21, Genesis 1:21...">kind</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1