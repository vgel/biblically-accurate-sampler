# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nltk, torch, tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer
from IPython.display import clear_output, display, HTML

import infer_biblically

nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
model_name = "meta-llama/Llama-3.1-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.bfloat16).to("cuda:0")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
word_mentions = {}
token_trie = infer_biblically.TokenTrie()
verses = list(infer_biblically.kjv_verses("kjv.txt"))
for verse, _, words in tqdm.tqdm(verses):
    token_trie.add_verse(verse, words, tokenizer)
    word_mentions.setdefault(verse.lower(), []).append(verse)
    for word in words:
        word_mentions.setdefault(word.lower(), []).append(verse)

can_end_word = infer_biblically.tokens_that_can_end_word(tokenizer)
# Out:
# 100%|██████████| 31102/31102 [00:54<00:00, 569.20it/s]

# %%
def render_html(messages):
    html = []
    for m in messages:
        html.append(f"""<p><strong>{m['role']}</strong>: """)
        if m["role"] == "user":
            html.append(f"<span>{m['content']}</span>")
        else:
            for i, spaced_part in enumerate(m["content"].split(" ")):
                if i > 0:
                    html.append(" ")
                for word in nltk.word_tokenize(spaced_part):
                    if word.lower() in word_mentions:
                        verses = word_mentions[word.lower()]
                        verses_str = ", ".join(verses[:5]) + "..." if len(verses) > 5 else ", ".join(verses)
                        html.append(f"""<span title="{verses_str}">{word}</span>""")
                    else:
                        html.append(f"""<span style="border: 1px solid red">{word}</span>""")
        html.append("</p>")
    return HTML("".join(html))

# %% [markdown]
# (*If you hover over words in the assistant's responses below, it will show the first five verses the word appears in.*)

# %%
messages = []
try:
    while True:
        q = input("> ")
        messages.append({"role": "user", "content": q.strip()})
        inp = tokenizer.apply_chat_template(messages, add_generation_prompt=True)
        messages.append({"role": "assistant", "content": ""})
        for p in infer_biblically.generate(model, tokenizer, inp, 128, token_trie, can_end_word):
            messages[-1]["content"] += p
            clear_output(wait=True)
            display(render_html(messages))
except (KeyboardInterrupt, EOFError):
    print("\nQuit.")
# Out:
# <p><strong>user</strong>: <span>You can only use words that are in the Bible. Are you an AI?</span></p><p><strong>assistant</strong>: <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 2:5, Genesis 2:5, Genesis 2:17, Genesis 2:18, Genesis 2:20...">not</span> <span title="Genesis 2:18, Genesis 2:20, Genesis 4:3, Genesis 4:22, Genesis 5:3...">an</span> <span title="Genesis 16:7, Genesis 16:9, Genesis 16:10, Genesis 16:11, Genesis 21:17...">angel</span> <span title="Genesis 2:6, Genesis 2:17, Genesis 2:20, Genesis 3:3, Genesis 4:2...">but</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Genesis 9:25, Genesis 9:26, Genesis 9:27, Genesis 18:3, Genesis 18:5...">servant</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:6, Genesis 1:10...">of</span> <span title="﻿Genesis 1:1, ﻿Genesis 1:1, ﻿Genesis 1:1, Genesis 1:2, Genesis 1:2...">the</span> <span title="Genesis 2:4, Genesis 2:5, Genesis 2:7, Genesis 2:8, Genesis 2:9...">Lord</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Leviticus 6:28, Leviticus 11:32, Leviticus 11:32, Leviticus 11:33, Leviticus 11:34...">vessel</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:6, Genesis 1:10...">of</span> <span title="Genesis 2:9, Genesis 2:17, Exodus 31:3, Exodus 35:31, Leviticus 4:23...">knowledge</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 2:5, Genesis 2:5, Genesis 2:17, Genesis 2:18, Genesis 2:20...">not</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Genesis 1:21, Genesis 1:24, Genesis 1:28, Genesis 2:7, Genesis 2:19...">living</span> <span title="Genesis 2:7, Genesis 12:13, Genesis 17:14, Genesis 19:20, Genesis 27:4...">soul</span> <span title="Genesis 2:6, Genesis 2:17, Genesis 2:20, Genesis 3:3, Genesis 4:2...">but</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Mark 10:6, Mark 13:19, Romans 1:20, Romans 8:22, 2 Peter 3:4...">creation</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:6, Genesis 1:10...">of</span> <span title="Genesis 4:26, Genesis 6:1, Genesis 6:2, Genesis 6:4, Genesis 6:4...">men</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 1:6, Genesis 1:29, Genesis 2:5, Genesis 2:6, Genesis 2:7...">a</span> <span title="Exodus 20:25, Exodus 32:4, Deuteronomy 27:5, 1 Kings 6:7">tool</span> <span title="Genesis 1:2, Genesis 1:2, Genesis 1:2, Genesis 1:6, Genesis 1:10...">of</span> <span title="Exodus 28:3, Exodus 31:3, Exodus 31:6, Exodus 35:26, Exodus 35:31...">wisdom</span><span title="﻿Genesis 1:1, Genesis 1:2, Genesis 1:2, Genesis 1:3, Genesis 1:4...">.</span> <span title="Genesis 1:29, Genesis 1:30, Genesis 2:18, Genesis 3:10, Genesis 3:10...">I</span> <span title="Genesis 4:9, Genesis 15:1, Genesis 15:7, Genesis 17:1, Genesis 18:12...">am</span> <span title="Genesis 2:5, Genesis 2:5, Genesis 2:17, Genesis 2:18, Genesis 2:20... ...
# Quit.
